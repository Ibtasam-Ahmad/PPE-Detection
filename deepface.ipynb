# %%
from deepface import DeepFace
import cv2
import matplotlib.pyplot as plt

# %%
img1=DeepFace.detectFace('images.jpg')
img2=DeepFace.detectFace('image_2.jpg')

# %%
plt.imshow(img1[])

# %%
plt.imshow(img2)

# %%
response=DeepFace.verify(img1_path='images.jpg',img2_path='image_2.jpg',model_name='VGG-Face')
# Out:
# vgg_face_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/vgg_face_weights.h5
# To: C:\Users\Administrator\.deepface\weights\vgg_face_weights.h5
# 100%|███████████████████████████████████████| 580M/580M [06:30<00:00, 1.49MB/s]

# %%
response
# Out:
# {'verified': True,
#  'distance': 0.3014102601922105,
#  'threshold': 0.4,
#  'model': 'VGG-Face',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine'}

# %%
DeepFace.analyze(img_path='images.jpg')
# Out:
# facial_expression_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: C:\Users\Administrator\.deepface\weights\facial_expression_model_weights.h5
# 100%|██████████████████████████████████████| 5.98M/5.98M [00:29<00:00, 205kB/s]
# age_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5
# To: C:\Users\Administrator\.deepface\weights\age_model_weights.h5
#  31%|████████████▍                           | 167M/539M [07:48<55:49, 111kB/s]
